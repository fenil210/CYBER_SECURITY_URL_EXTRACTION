# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.datasets import make_classification
from sklearn.naive_bayes import GaussianNB  
from sklearn.metrics import precision_recall_fscore_support as score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers 
from keras.models import Sequential  
from keras.layers import *  
from sklearn.model_selection import validation_curve
from sklearn.model_selection import GridSearchCV, KFold

# %%
import gc
import re
import string
import operator
from collections import defaultdict
import tokenization
from wordcloud import STOPWORDS

from sklearn.model_selection import StratifiedKFold, StratifiedShuffleSplit

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.layers import Dense, Input, Dropout, GlobalAveragePooling1D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, Callback

SEED = 1337

# %%
df=pd.read_csv('data4.csv')

# %%
df.tail()
# Out:
#       Unnamed: 0       eventid  month              region  \
# 4955        4955  2.021060e+11      6          South Asia
# 4956        4956  2.021060e+11      6      Southeast Asia
# 4957        4957  2.021060e+11      6  Sub-Saharan Africa
# 4958        4958  2.021060e+11      6       South America
# 4959        4959  2.021070e+11      6      Southeast Asia
#
#                                                 summary  success  suicide  \
# 4955   An explosive device detonated targeting an el...        1        0
# 4956   Assailants abducted and killed U Maung Zaw, a...        1        0
# 4957   Assailants abducted Reverend Father Elijah Ju...        1        0
# 4958   Security forces discovered and defused an exp...        0        0
# 4959   An explosion occurred at a casino in Kaungmut...        1        0
#
#                       attacktype1                        targtype  \
# 4955            Bombing/Explosion                       Utilities
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4960 entries, 0 to 4959
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        4960 non-null   int64
#  1   eventid           4960 non-null   float64
#  2   imonth            4960 non-null   int64
#  3   region_txt        4960 non-null   object
#  4   Summary           4960 non-null   object
#  5   success           4960 non-null   int64
#  6   suicide           4960 non-null   int64
#  7   attacktype1_txt   4960 non-null   object
#  8   targtype1_txt     4960 non-null   object
#  9   target1           4960 non-null   object
#  10  gname             4960 non-null   object
#  11  weaptype1_txt     4960 non-null   object
#  12  weapsubtype1_txt  4167 non-null   object
#  13  scite1            4960 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 542.6+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0       eventid       imonth      success      suicide
# count  4960.000000  4.960000e+03  4960.000000  4960.000000  4960.000000
# mean   2479.500000  2.021037e+11     3.744960     0.851613     0.015927
# std    1431.972998  1.719046e+06     1.717634     0.355519     0.125207
# min       0.000000  2.021010e+11     1.000000     0.000000     0.000000
# 25%    1239.750000  2.021020e+11     2.000000     1.000000     0.000000
# 50%    2479.500000  2.021040e+11     4.000000     1.000000     0.000000
# 75%    3719.250000  2.021050e+11     5.000000     1.000000     0.000000
# max    4959.000000  2.021070e+11     6.000000     1.000000     1.000000

# %%
df.shape
# Out:
# (4960, 15)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# specify the URL of the website to scrape
url = 'https://www.example.com/blog/'

# send a GET request to the website's URL
response = requests.get(url)

# parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# find all the <p> tags that contain the blog content
blog_content = soup.find_all('p')

# extract the text content from the <p> tags
blog_lines = [p.get_text() for p in blog_content]

# select 2000 random lines of text from the extracted content
random_lines = random.sample(blog_lines, 2000)

# create a DataFrame to store the extracted text
df1 = pd.DataFrame({'conversation': random_lines})

# print the first 10 lines of the extracted text
print(df1.head(10))

# %%
df=pd.read_csv('data4.csv')

# %%
df.head(20)
# Out:
#     eventid                      region  \
# 0      1061  Middle East & North Africa
# 1      2310          Sub-Saharan Africa
# 2      4228          Sub-Saharan Africa
# 3       964  Middle East & North Africa
# 4      3165                  South Asia
# 5      6644                  South Asia
# 6      1772  Middle East & North Africa
# 7      5143          Sub-Saharan Africa
# 8      6945                  South Asia
# 9       188          Sub-Saharan Africa
# 10     4880              Southeast Asia
# 11      723          Sub-Saharan Africa
# 12     4204          Sub-Saharan Africa
# 13      823                  South Asia
# 14     5585  Middle East & North Africa
# 15     1188          Sub-Saharan Africa
# 16     4858                  South Asia
# 17     6432                  South Asia
# 18     1679          Sub-Saharan Africa
# 19     2548                  South Asia
#
#                                               summary  success  suicide  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6960 entries, 0 to 6959
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   eventid      6960 non-null   int64
#  1   region       6960 non-null   object
#  2   summary      6960 non-null   object
#  3   success      6960 non-null   int64
#  4   suicide      6960 non-null   int64
#  5   attacktype   4960 non-null   object
#  6   targtype     4960 non-null   object
#  7   target       4960 non-null   object
#  8   gname        4960 non-null   object
#  9   weaptype     4960 non-null   object
#  10  weapsubtype  4167 non-null   object
#  11  site         6960 non-null   object
#  12  target.1     6960 non-null   int64
# dtypes: int64(4), object(9)
# memory usage: 707.0+ KB

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from keras.models import Sequential,Model
from keras.layers import Dense,LSTM, SpatialDropout1D, Embedding
from keras.utils.np_utils import to_categorical
from joblib import dump, load
from sklearn.feature_extraction.text import CountVectorizer
